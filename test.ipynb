# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16)
pipe.to("cuda")

image = pipe(prompt="yoda").images[0]
image
# Out:
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:03<00:02,  1.00it/s]/home/users/chokun_nap/miniconda3/envs/t2i/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...
# 100%|██████████| 50/50 [00:03<00:00, 13.47it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_path = "output/sd-naruto-model"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16)
pipe.to("cuda")
torch.manual_seed(42)
image = pipe(prompt="John Oliver with Naruto style").images[0]
image
# Out:
# ...
# 100%|██████████| 50/50 [00:04<00:00, 12.21it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_path = "output/sd-naruto-model"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16)
pipe.to("cuda")
torch.manual_seed(42)
image = pipe(prompt="John Oliver with Naruto style").images[0]
image
# Out:
# ...
# 100%|██████████| 50/50 [00:01<00:00, 38.65it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

torch.manual_seed(42)

model_path = "output/sd-naruto-model"
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16)
pipe.to("cuda")

image = pipe(prompt="John Oliver with Naruto style").images[0]
image
# Out:
# ...
# 100%|██████████| 50/50 [00:03<00:00, 15.58it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
